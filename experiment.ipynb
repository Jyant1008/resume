# %%
import os
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS


def extract_text_from_pdfs(folder_path):
    """
    Reads all PDF files from the given folder path and extracts text.
    :param folder_path: Path to the folder containing PDFs
    """
    GROQ_API_KEY = "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"
    NOMIC_API_KEY="nk-QA1x9zLAbGUNnH7kZVLQX157E9jn6cn5vmyYOQJs090"
    if not os.path.exists(folder_path):
        print("The provided folder path does not exist.")
        return
    
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]
    
    if not pdf_files:
        print("No PDF files found in the folder.")
        return
    
    for pdf_file in pdf_files:
        pdf_path = os.path.join(folder_path, pdf_file)
        loader = PyPDFLoader(pdf_path)
        doc = loader.load()
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
        documents = text_splitter.split_documents(doc)
        database = FAISS.from_documents(documents,embedding=embeddings)
            
            
        

# Example usage
folder_path = "C:/Users/Jyant/Desktop/resumeprocess/all_resume"  # Replace with the actual folder path
extract_text_from_pdfs(folder_path)
# Out:
# Extracting text from: Daksh_Yadav resume.pdf
#
# DAKSH YADAV +91-8814850067|yadavdaksh600@gmail.com|LinkedIn  EDUCATION AND ACADEMIC ACHIEVEMENTS Course/Examination      Year                    Institution/Board Grade M.Tech. Applied Mathematics and Scientific Computing 2023-2025 Indian Institute of Technology Roorkee 8/10 M.Sc. Mathematics 2020-2022 Indian Institute of Technology Palakkad 6.99/10 B.Sc. (Hons.) Mathematics 2017-2020 Sri Venkateswara College, University of Delhi 8.473/10 AISSCE (Class XII) 2017 Rao Pahlad Singh Public School,
# --------------------------------------------------
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
temp_file = "C:/Users/Jyant/Desktop/resumeprocess/all_resume/Daksh_Yadav resume.pdf"

# Pass the BytesIO object directly to PyPDFLoader
loader = PyPDFLoader(temp_file)
doc = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
documents = text_splitter.split_documents(doc)
# Out:
# 0

# %%
temp_file = "C:/Users/Jyant/Desktop/resumeprocess/all_resume/Daksh_Yadav resume.pdf"
doc = fitz.open(temp_file)

# %%
for page in doc:
    print(page.get_text("text"))
